# %% [markdown]
# <a href="https://colab.research.google.com/github/ManasiMhatre22/Data-Compression/blob/master/Sargam_Tune_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpleaudio

# %%
import numpy as np
import simpleaudio as sa
from itertools import repeat

# %%
sargamdict = {"sa":261,
             "re":294,
             "ga":330,
             "ma":349,
             "pa":392,
             "dha":440,
             "ni":494,
             "sa1":515}

# %%
def play_audio(audio):# normalize to 16-bit range
    audio *= 32767 / np.max(np.abs(audio))
    # convert to 16-bit data
    audio = audio.astype(np.int16)

    # start playback
    play_obj = sa.play_buffer(audio, 1, 2, sample_rate)

    # wait for playback to finish before exiting
    play_obj.wait_done()

# %%
# get timesteps for each sample, T is note duration in seconds
# For CD recordings, the industry standard is to store each audio sample 
# as a 16-bit value, at 44100 samples per second.
sample_rate = 44100
T =int(0.25)
t = np.linspace(0, T,T * sample_rate, endpoint=False)

# %%
# generate sine wave notes for sa re ga ma
Sa_note = np.sin(sargamdict["sa"] * t * 3 * np.pi)
Re_note = np.sin(sargamdict["re"] * t * 3 * np.pi)
Ga_note = np.sin(sargamdict["ga"] * t * 3* np.pi)
Ma_note = np.sin(sargamdict["ma"] * t * 3 * np.pi)
Pa_note = np.sin(sargamdict["pa"] * t * 3 * np.pi)
Dha_note = np.sin(sargamdict["dha"] * t * 3 * np.pi)
Ni_note = np.sin(sargamdict["ni"] * t * 3 * np.pi)
Sa1_note = np.sin(sargamdict["sa1"] * t * 3 * np.pi)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(40,20))
plt.plot(t, Sa_note);

# %%
get_pause  = lambda seconds: repeat(0, int(seconds * sample_rate))

# %%
pause_note=list(get_pause(0.01))

# %%
sargam = np.hstack((pause_note,Sa_note,pause_note,Re_note,pause_note,Ga_note,
                   pause_note,Ma_note, pause_note,Pa_note, pause_note,
                    Dha_note, pause_note,Ni_note, pause_note, Sa1_note,pause_note))

# %%
type(sargam)
# Out:
# numpy.ndarray

# %%
sargam.shape
# Out:
# (92169,)

# %%
play_audio(sargam)
play_audio(sargam[::-1])
# Out:
# C:\Users\aiktc\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars
#
# C:\Users\aiktc\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
# !pip install wavio

# %%
import wavio
fs = 44100 
s2 = np.append(sargam,sargam[::-1])
wavio.write("pythonsargam.wav", s2, fs, scale=None,sampwidth=3)

# %%
# All frequences - soft and main
Ni1 = 220
s = 224
Sa = 240
r = 256
Re = 270
g = 288
Ga = 300
m = 320
Ma = 337.5
Pa = 360 
d = 384
Dha = 400
Ni = 450
Sa1 = 480

# %%
# generate sine wave notes for sa re ga ma
Ni1_note = np.sin(Ni1 * t * 3 * np.pi)
Sa_note = np.sin(Sa * t * 3 * np.pi)
Re_note = np.sin(Re * t * 3 * np.pi)
Ga_note = np.sin(Ga * t * 3* np.pi)
Ma_note = np.sin(Ma * t * 3 * np.pi)
Pa_note = np.sin(Pa * t * 3 * np.pi)
Dha_note = np.sin(Dha * t * 3 * np.pi)
Ni_note = np.sin(Ni * t * 3 * np.pi)
Sa1_note = np.sin(Sa1 * t * 3 * np.pi)
s_note = np.sin(s * t * 3 * np.pi)
r_note = np.sin(r * t * 3 * np.pi)
g_note = np.sin(g * t * 3 * np.pi)
m_note = np.sin(m * t * 3 * np.pi)
d_note = np.sin(d * t * 3 * np.pi)

# %%
audio1 = np.hstack((Re_note, Sa_note, pause_note,Ga_note, Sa_note, 
                    Re_note, Ni1_note, Sa_note, Ni1_note, pause_note,
                    Re_note, Sa_note, pause_note, Ga_note, Sa_note,
                    Re_note, Ni1_note,Sa_note, Sa_note,
                    pause_note,
                    Re_note, Ga_note, Ga_note,Pa_note, Pa_note,
                    d_note, d_note, pause_note, Pa_note, Pa_note, 
                    d_note, d_note, pause_note, Pa_note, Pa_note, 
                    d_note, d_note, Pa_note,
                    Re_note, Ga_note, Ga_note, m_note, m_note, 
                    Pa_note, Pa_note,
                    m_note, m_note, Pa_note,Pa_note,
                    m_note, m_note, Ga_note, Re_note, Sa_note,
                    pause_note,
                    Re_note, Sa_note, Ga_note, Sa_note, 
                    Re_note, Ni1_note, Sa_note, Ni1_note,
                    Re_note, Sa_note, Ga_note, Sa_note,
                    Re_note, Ni1_note,Sa_note, Sa_note))

# %%
play_audio(audio1)
# Out:
# C:\Users\aiktc\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars
#
# C:\Users\aiktc\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
import wavio
fs = 44100 
s2 = np.append(audio1, audio1)
wavio.write("naagin.wav", s2, fs, scale=None,sampwidth=3)
